# %%
Exception: (exact same way it wokrs as java)
1. Syntax Errors
2. Runtime Errors

# %%
if 5>4
    print("hello")
# Out:
#   File "<ipython-input-1-1c9fb788b7f7>", line 1
#     if 5>4
#           ^
# SyntaxError: invalid syntax

# %%
print(10/4)
print(10/0)
# Out:
# 2.5
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-62dc3fd63f64> in <module>()
#       1 print(10/4)
# ----> 2 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
print(10/"ten")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-765c72deb1f8> in <module>()
# ----> 1 print(10/"ten")
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
Default Exception Handling:
    every exception in python are objects. objects are created by JVM and goes for except block. 
    it handling code is not available, python intropreter stop the program abnormally and print message in console.

# %%
from IPython.display import Image
Image(filename="/notebooks/exception.png")

# %%
#How to pring exception message:
try:
    print(10/0)
except ZeroDivisionError as msg:
    print(msg)
# Out:
# division by zero

# %%
try:
    print(10/0)
except BaseException as msg:
    print(msg , "kk")
except ZeroDivisionError as msg:
    print(msg ,"kiyan")
# Out:
# division by zero kk

# %%
try:
    print(10/0)
except ZeroDivisionError as msg:
    print(msg ,"kiyan")
except BaseException as msg:
    print(msg , "kk")
# Out:
# division by zero kiyan

# %%
# except blocks work from top to bottom, if no corresponding matched exception found. then it is abnormal termination
try:
    print(10/a)
except ZeroDivisionError as msg:
    print(msg ,"kiyan")
except NameError as msg:
    print(msg ,"kumar")
except BaseException as msg:
    print(msg , "kk")
# Out:
# name 'a' is not defined kumar

# %%
#Since parent except is top, it is executed first
try:
    print(10/0)
except BaseException as msg:
    print(msg , "kk")
except ZeroDivisionError as msg:
    print(msg ,"kiyan")
# Out:
# division by zero kk

# %%
#Mulitiple Exception:
try:
    print(10/0)
except (ZeroDivisionError,NameError) as msg: #tuple of errors
    print(msg ,"kiyan")
except BaseException as msg:
    print(msg , "kk")
# Out:
# division by zero kiyan

# %%
#default Exception:
# it must be the last
# we can not send message like except as msg.
try:
    print(10/a)
except (ZeroDivisionError,TypeError) as msg:
    print(msg ,"kiyan")
except:
    print("default Exception block")
# Out:
# default Exception block

# %%
5 possibilities:
    except ZeroDivisionError:
    except ZeroDivisionError as msg:
    except ZeroDivisionError,TypeError:
    except ZeroDivisionError,TypeError as msg:
    except:

# %%
finally : For cleanup. before abnormal termination finally block executes then abnormal termination. 
finally block executes always except os ._exit(0) executes in try/except blocks.
Note: If the control entered into try block then compulsary finally block will be executed.
If the control not entered into try block then finally block won't be executed.

# %%
Nested try except. as it is java

# %%
Control Flow in nested try-except-finally:

try:
    stmt-1
    stmt-2
    stmt-3
    try:
        stmt-4
        stmt-5
        stmt-6
    except X:
        stmt-7
    finally:
        stmt-8
    stmt-9
except Y:
    stmt-10
finally:
    stmt-11
stmt-12

Case-1: If there is no exception
1,2,3,4,5,6,8,9,11,12 Normal Termination

Case-2: If an exception raised at stmt-2 and the corresponding except block matched
1,10,11,12 Normal Termination

Case-3: If an exceptiion raised at stmt-2 and the corresponding except block not matched
1,11,Abnormal Termination

Case-4: If an exception raised at stmt-5 and inner except block matched
1,2,3,4,7,8,9,11,12 Normal Termination

Case-5: If an exception raised at stmt-5 and inner except block not matched but outer
except block matched 1,2,3,4,8,10,11,12,Normal Termination

Case-6:If an exception raised at stmt-5 and both inner and outer except blocks are not
matched 1,2,3,4,8,11,Abnormal Termination

Case-7: If an exception raised at stmt-7 and corresponding except block matched
1,2,3,.,.,.,8,10,11,12,Normal Termination

Case-8: If an exception raised at stmt-7 and corresponding except block not matched
1,2,3,.,.,.,8,11,Abnormal Termination

Case-9: If an exception raised at stmt-8 and corresponding except block matched
1,2,3,.,.,.,.,10,11,12 Normal Termination

Case-10: If an exception raised at stmt-8 and corresponding except block not matched
1,2,3,.,.,.,.,11,Abnormal Termination

Case-11: If an exception raised at stmt-9 and corresponding except block matched
1,2,3,.,.,.,.,8,10,11,12,Normal Termination

Case-12: If an exception raised at stmt-9 and corresponding except block not matched
1,2,3,.,.,.,.,8,11,Abnormal Termination

Case-13: If an exception raised at stmt-10 then it is always abonormal termination but
before abnormal termination finally block(stmt-11) will be executed.

Case-14: If an exception raised at stmt-11 or stmt-12 then it is always abnormal
termination.

# %%
try-except-else-finally Block: else block will execute only whentry block executes sucessfully. if control goes to 
    except block then else block will not execute. Refer below two program output.

# %%
try:
    print("try")
    print(10/2)
except:
    print("except")
else:
    print("else")
finally:
    print("finally")
# Out:
# try
# 5.0
# else
# finally

# %%
try:
    print("try")
    print(10/0)
except:
    print("except")
else:
    print("else")
finally:
    print("finally")
# Out:
# try
# except
# finally

# %%
independant try blocks are not allowed. it should be in the combination of  except / finally / both.
independant except/else/finally blocks are not allowed.
in between blocks there should not be independant statements
multiple else statement not allowed
multiple finally statement not allowed.
try/finally block allowed.
else without except block not allowed
Inside except block try-except-finally block allowed.
Inside finally block try-except-finally block allowed.

# %%
PreDefined Exception & UserDefined Exception: we already coverd predefined excepton. 
    Now we will go userdefined exception
InsufficentBalance
InvalidAgeException

we have to use constructors in user Defined Exception. __init__

# %%
class InvalidAgeException(Exception):
    def __init__(self,args):
        self.msg = args
class InSufficientBlance(Exception):
    def __init__(self,args):
        self.msg = args

# %%
raise(InvalidAgeException("your age not matching"))
# Out:
# ---------------------------------------------------------------------------
# InvalidAgeException                       Traceback (most recent call last)
# <ipython-input-18-bf65a9866c80> in <module>()
# ----> 1 raise(InvalidAgeException("your age not matching"))
#
# InvalidAgeException: your age not matching

# %%
logging:

6 levels of logging:
    CRITICAL
    ERROR
    WARNING
    INFO
    DEBUG
    NOSET

# %%
from importlib import reload
import logging
reload(logging)
logging.basicConfig(filename="/notebooks/log.txt",level=logging.WARNING)
logging.critical("hey this critcal message")
logging.error("hey this ERROR message")
logging.warning("hey this WARNING message")
logging.info("hey this INFO message")
logging.debug("hey this DEBUG message")

# %%
it will create a log.txt file if not exist and add logging information of WARNING and above.
default level is logging.WARNING. if we want to capture info and debug also we have to set level=logging.DEBUG
new logging statement add messages to at the end of file.

# %%
from importlib import reload
reload(logging)
logging.basicConfig(filename="log.txt", level=logging.DEBUG)
logging.critical("hey this critcal message")
logging.error("hey this ERROR message")
logging.warning("hey this WARNING message")
logging.info("hey this INFO message")
logging.debug("hey this DEBUG message")

# %%
#logging.exception = > to capture error messages of exceptions.
try:
    print(10/0)
except ZeroDivisionError as msg:
    logging.exception(msg)
except ValueError as msg:
    logging.exception(msg)

# %%
from IPython.display import Image
Image(filename="/notebooks/logs.png")

# %%
Assertion:
    for debuging we use assertion
    there are two types.
    1. simple version -> assert condition
    2. agumented version -> assert condition message

# %%
x=10
assert x>10
print(x)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-24-04d707d4af4f> in <module>()
#       1 x=10
# ----> 2 assert x>10
#       3 print(x)
#
# AssertionError:

# %%
x=10
assert x>10, "here x value should be greater than 10"
print(x)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-25-b2da3a179ce8> in <module>()
#       1 x=10
# ----> 2 assert x>10, "here x value should be greater than 10"
#       3 print(x)
#
# AssertionError: here x value should be greater than 10

# %%
we can skip assertion statement by using py -0 myTest.py -> here because of -0 assert statment will not execute.
